# %%
import os
import sys
sys.path.insert(0, '..')
import pickle
import glob

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

import gym
import load_policy

# %matplotlib inline

# %%
for i in sorted(glob.glob('dagger-models/trained-with-dagger-*/mse_train_test.csv')):
    df_da = pd.read_csv(i)
    plt.plot(df_da.test_mse, label=i)
    plt.legend()
    plt.xlabel('# epochs')
    plt.ylabel('MSE')
    plt.grid()
    plt.ylim(0, 0.01)
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
