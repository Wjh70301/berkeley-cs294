# %%
from eda_imports import *

# %% [markdown]
# # Small batch, no reward_to_go, no normalize_advantage

# %%
infiles = sorted(glob.glob('./data/sb_no_rtg_no_na/CartPole-v0/*.csv'), 
                 key=lambda s: int(os.path.basename(s).replace('.csv', '')))
print(len(infiles))
# Out:
# 4

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 4))
axes = axes.ravel()

for k, col in enumerate(['avg_ret', 'min_ret', 'max_ret']):
    ax = axes[k]
    
    dfs = []
    for f in infiles:
        _df = pd.read_csv(f)
        dfs.append(_df[col])

    cat_df = pd.concat(dfs, axis=1)
#     cat_df.columns=np.arange(1, 6)

    avg = cat_df.mean(axis=1)
    std = cat_df.std(axis=1)

    xs = cat_df.index.values + 1

    ax.plot(xs, avg)
    ax.fill_between(xs, avg - std, avg+std, alpha=0.2)
    ax.set_title(col)
    ax.grid()

# %% [markdown]
# # Large batch, no reward_to_go, no normalize_advantage

# %%
infiles = sorted(glob.glob('./data/lb_no_rtg_no_na/CartPole-v0/*.csv'), 
                 key=lambda s: int(os.path.basename(s).replace('.csv', '')))
print(len(infiles))
# Out:
# 4

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 4))
axes = axes.ravel()

for k, col in enumerate(['avg_ret', 'min_ret', 'max_ret']):
    ax = axes[k]
    
    dfs = []
    for f in infiles:
        _df = pd.read_csv(f)
        dfs.append(_df[col])

    cat_df = pd.concat(dfs, axis=1)
#     cat_df.columns=np.arange(1, 6)

    avg = cat_df.mean(axis=1)
    std = cat_df.std(axis=1)

    xs = cat_df.index.values + 1

    ax.plot(xs, avg)
    ax.fill_between(xs, avg - std, avg+std, alpha=0.2)
    ax.set_title(col)
    ax.grid()

# %% [markdown]
# # Small batch, reward_to_go, no normalize_advantage

# %%
infiles = sorted(glob.glob('./data/sb_rtg_no_na/CartPole-v0/*.csv'), 
                 key=lambda s: int(os.path.basename(s).replace('.csv', '')))
print(len(infiles))
# Out:
# 4

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 4))
axes = axes.ravel()

for k, col in enumerate(['avg_ret', 'min_ret', 'max_ret']):
    ax = axes[k]
    
    dfs = []
    for f in infiles:
        _df = pd.read_csv(f)
        dfs.append(_df[col])

    cat_df = pd.concat(dfs, axis=1)

    avg = cat_df.mean(axis=1)
    std = cat_df.std(axis=1)

    xs = cat_df.index.values + 1

    ax.plot(xs, avg)
    ax.fill_between(xs, avg - std, avg+std, alpha=0.2)
    ax.set_title(col)
    ax.grid()

# %% [markdown]
# # Large batch, reward_to_go, no normalize_advantage

# %%
infiles = sorted(glob.glob('./data/lb_rtg_no_na/CartPole-v0/*.csv'), 
                 key=lambda s: int(os.path.basename(s).replace('.csv', '')))
print(len(infiles))
# Out:
# 4

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 4))
axes = axes.ravel()

for k, col in enumerate(['avg_ret', 'min_ret', 'max_ret']):
    ax = axes[k]
    
    dfs = []
    for f in infiles:
        _df = pd.read_csv(f)
        dfs.append(_df[col])

    cat_df = pd.concat(dfs, axis=1)
#     cat_df.columns=np.arange(1, 6)

    avg = cat_df.mean(axis=1)
    std = cat_df.std(axis=1)

    xs = cat_df.index.values + 1

    ax.plot(xs, avg)
    ax.fill_between(xs, avg - std, avg+std, alpha=0.2)
    ax.set_title(col)
    ax.grid()

# %% [markdown]
# # Small batch, reward_to_go, normalize_advantage

# %%
infiles = sorted(glob.glob('./data/sb_rtg_na/CartPole-v0/*.csv'), 
                 key=lambda s: int(os.path.basename(s).replace('.csv', '')))
print(len(infiles))
# Out:
# 4

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 4))
axes = axes.ravel()

for k, col in enumerate(['avg_ret', 'min_ret', 'max_ret']):
    ax = axes[k]
    
    dfs = []
    for f in infiles:
        _df = pd.read_csv(f)
        dfs.append(_df[col])

    cat_df = pd.concat(dfs, axis=1)

    avg = cat_df.mean(axis=1)
    std = cat_df.std(axis=1)

    xs = cat_df.index.values + 1

    ax.plot(xs, avg)
    ax.fill_between(xs, avg - std, avg+std, alpha=0.2)
    ax.set_title(col)
    ax.grid()

# %% [markdown]
# # Large batch, reward_to_go, normalize_advantage

# %%
infiles = sorted(glob.glob('./data/lb_rtg_na/CartPole-v0/*.csv'), 
                 key=lambda s: int(os.path.basename(s).replace('.csv', '')))
print(len(infiles))
# Out:
# 3

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 4))
axes = axes.ravel()

for k, col in enumerate(['avg_ret', 'min_ret', 'max_ret']):
    ax = axes[k]
    
    dfs = []
    for f in infiles:
        _df = pd.read_csv(f)
        dfs.append(_df[col])

    cat_df = pd.concat(dfs, axis=1)

    avg = cat_df.mean(axis=1)
    std = cat_df.std(axis=1)

    xs = cat_df.index.values + 1

    ax.plot(xs, avg)
    ax.fill_between(xs, avg - std, avg+std, alpha=0.2)
    ax.set_title(col)
    ax.grid()

# %% [markdown]
# # Q & A

# %% [markdown]
# reward-to-go and advantage normalization help, but not as apparent as batch size, which makes a huge impact.
#
# The empirical results do match theory: with policy gradient, the expected return improves, which is the goal of RL.

# %% [markdown]
# # Small batch, reward_to_go, normalize_advantage, neural network baseline

# %%
infiles = sorted(glob.glob('./data/sb_rtg_na_nb/CartPole-v0/*.csv'), 
                 key=lambda s: int(os.path.basename(s).replace('.csv', '')))
print(len(infiles))
# Out:
# 5

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 4))
axes = axes.ravel()

for k, col in enumerate(['avg_ret', 'min_ret', 'max_ret']):
    ax = axes[k]
    
    dfs = []
    for f in infiles:
        _df = pd.read_csv(f)
        dfs.append(_df[col])

    cat_df = pd.concat(dfs, axis=1)

    avg = cat_df.mean(axis=1)
    std = cat_df.std(axis=1)

    xs = cat_df.index.values + 1

    ax.plot(xs, avg)
    ax.fill_between(xs, avg - std, avg+std, alpha=0.2)
    ax.set_title(col)
    ax.grid()

# %% [markdown]
# # Large batch, reward_to_go, normalize_advantage, neural network baseline

# %%
infiles = sorted(glob.glob('./data/lb_rtg_na_nb/CartPole-v0/*.csv'), 
                 key=lambda s: int(os.path.basename(s).replace('.csv', '')))
print(len(infiles))
# Out:
# 5

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 4))
axes = axes.ravel()

for k, col in enumerate(['avg_ret', 'min_ret', 'max_ret']):
    ax = axes[k]
    
    dfs = []
    for f in infiles:
        _df = pd.read_csv(f)
        dfs.append(_df[col])

    cat_df = pd.concat(dfs, axis=1)

    avg = cat_df.mean(axis=1)
    std = cat_df.std(axis=1)

    xs = cat_df.index.values + 1

    ax.plot(xs, avg)
    ax.fill_between(xs, avg - std, avg+std, alpha=0.2)
    ax.set_title(col)
    ax.grid()
